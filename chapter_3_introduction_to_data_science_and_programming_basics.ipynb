# %% [markdown]
# <a href="https://colab.research.google.com/github/IrinaViolin/DataSIENCE-IRINA/blob/main/chapter_3_introduction_to_data_science_and_programming_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Основы Python**

# %% [markdown]
# ##**3.1. Запуск Python**

# %% [markdown]
# Настало время изучить основы языка программирования Python. Необходимо, чтобы вы проделывали самостоятельно все, что мы будем обсуждать. Для этого нужно
# открыть Spyder IDE или Jupyter Notebook. И поэтому сперва я расскажу вам об
# основах работы с этими программами, а затем вы сможете поэкспериментировать
# самостоятельно и узнать больше

# %% [markdown]
# Для создания этой книги я использовал Jupyter Notebook, и вы увидите сходство
# этой книги с оформлением документов. Jupyter Notebook — это хорошая отправная
# точка для начала обучения. Вы можете запускать свой код в ячейках кода и писать
# свой текст в ячейках Markdown.

# %% [markdown]
# ##**3.1.1. Использование Spyder IDE**

# %% [markdown]
# Интегрированная среда разработки Spyder имеет свой графический интерфейс. Мы
# уже установили приложение Anaconda, в состав которого входит и Spyder. Поэтому
# сначала откройте Anaconda Navigator (см. рис. 2.14).

# %% [markdown]
# Нажмите кнопку Launch под приложением Spyder. Откроется первое окно Spyder
# IDE со временным файлом (рис. 3.1).

# %% [markdown]
# Для начала изучения нам понадобятся три основных компонента Spyder IDE
# (рис. 3.2). Вы узнаете больше о компонентах или функциях, когда начнете работу
# со средой.

# %% [markdown]
# * **Редактор**.
# Редактор Spyder во многих отношениях лучше простого текстового
# редактора. Помните, что это IDE, и, следовательно, ее функционал гораздо шире
# и включает в себя, например, нумерацию строк, выделение синтаксиса (ключевые слова в синтаксисе подсвечиваются цветом), функции автозаполнения и
# многое другое. В этом многоязычном редакторе вы можете эффективно работать
# с функциями и классами, пользоваться инструментами анализа кода, автоматическим завершением кода, горизонтальным/вертикальным разделением и переходом к определению объекта

# %% [markdown]
# * **Консоль IPython**.
# Вам доступны возможности любого количества консолей
# IPython в сочетании с гибкостью графического интерфейса. Вы можете запускать код по строкам, ячейкам или файлам, а также отображать графики прямо
# в строке.

# %% [markdown]
# * **Обозреватель переменных**.
# Этот компонент позволяет взаимодействовать
# с переменными и изменять их на лету, строить гистограмму или временной ряд,
# редактировать датафреймы или массивы NumPy, сортировать коллекции,
# копаться во вложенных объектах и многое другое!

# %% [markdown]
# Многие подробности станут понятнее по мере вашего прогресса в обучении, особенно если вы сами будете изучать новые вещи и экспериментировать в среде IDE.

# %% [markdown]
# Если говорить просто, то в редакторе мы что-то пишем (в том числе код). Консоль
# IPython— это окно консоли, подобное командной строке, в котором выводятся
# результаты выполнения кода и которое можно использовать независимо от редактора. В окне обозревателя переменных отображаются создаваемые объекты: новые
# переменные, классы, фреймы данных, диаграммы, графики и т. д.

# %% [markdown]
# ##**3.1.2. Использование Jupyter Notebook**

# %% [markdown]
# Jupyter Notebook также входит в состав Anaconda, поэтому снова откройте окно
# Anaconda Navigator. Нажмите кнопку Launch под приложением Jupyter Notebook.
# Стартовое окно Jupyter Notebook откроется в браузере, который установлен по
# умолчанию (рис. 3.3).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Папки, которые вы увидите, могут отличаться от моих, т. к. по умолчанию Jupyter
# Notebook открывается на папке вашего пользователя. На рис. 3.3 видно, что в моей
# личной папке уже есть несколько файлов ipynb. Чтобы открыть любой из них, достаточно щелкнуть по нему мышью

# %% [markdown]
# Но вы запустили программу впервые, вам нужно создать первый документ

# %% [markdown]
# Чтобы создать документ Notebook, нажмите на кнопку New в правом верхнем углу
# и выберите пункт меню Python 3 (рис. 3.3). Откроется новая веб-страница с одной
# пустой ячейкой и без имени (с именем Untitled в строке заголовка).

# %% [markdown]
# Теперь вы можете добавлять в документ любое количество ячеек, удалять их, изменять порядок отображения и многое другое.
# На рис. 3.4 показана страница моего документа Jupyter Notebook, открытого на этой главе, и подписаны различные элементы окна. По мере работы с этой программой вы узнаете больше о ее возможностях.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Чтобы запустить строку кода, просто введите ее в ячейку, оставьте тип ячейки
# Code (который задан по умолчанию) и используйте любой из способов запуска:

# %% [markdown]
# * с помощью мыши — откройте пункт меню Cell. Используйте любой из вариантов запуска, какой вам подходит;
# * с помощью клавиатуры — к пунктам меню Cell можно обращаться с помощью горячих клавиш.
#
#   Вот три наиболее часто используемых сочетания клавиш для
# запуска кода:

# %% [markdown]
# * Shift+Enter — запустить ячейку и перейти к следующей;
# * Ctrl+Enter — запустить выбранные ячейки;
# * Alt+Enter — запустить ячейку и вставить новую ниже

# %% [markdown]
# ##**3.2. Начнем с «Hello World!»**

# %% [markdown]
# Давайте продолжим традицию изучать компьютерное программирование проверенным поколениями методом — с помощью «Hello World!».

# %% [markdown]
# Мы уже видели такую программу, когда пробовали писать первый код. Давайте
# напишем то же самое еще раз в Spyder IDE или в Jupyter Notebook.

# %%
In [1]: print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Команда пишется в окне редактора Spyder IDE, а затем нужно открыть меню Run.
# Используйте пункт меню Run selection or current line, чтобы запустить эту минипрограмму. Результат работы появится в окне консоли.
#
#
# **Горячая клавиша для запуска кода — F9**

# %% [markdown]
# Если вы используете Jupyter Notebook, то для запуска кода используйте горячие
# клавиши или мышь, как было рассказано в предыдущем разделе.

# %% [markdown]
# Обычно слово «print» в программировании не означает, что результат будет напечатан на вашем принтере. Имеется в виду отображение результата команды на
# экране. То же самое и с функцией print ().

# %% [markdown]
# ##**3.3. Использование Python как калькулятора**

# %% [markdown]
# Давайте попробуем выполнить несколько простых команд Python.
# Запустите Spyder
# IDE и введите приведенные ниже команды в редакторе.
#
#   Сравните ваш вывод
# с моим выводом здесь и посмотрите, получите ли вы такие же результаты.

# %% [markdown]
# ##**3.3.1. Числа**

# %% [markdown]
# Интерпретатор Python можно использовать как простой калькулятор: мы вводим
# в него выражение, а он возвращает значение. Синтаксис выражений прост: арифметические операторы +, -, * и / работают так же, как в любой компьютерной программе, которую вы могли использовать, например, в цифровом калькуляторе или
# электронной таблице Excel; круглые скобки (), как обычно, могут использоваться
# для группировки. Например:

# %%
In [2]: 2+2
# Out:
# 4

# %%
In [3]: 50 - 5 * 6
# Out:
# 20

# %%
In [4]: (50 - 5 * 6) /4
# Out:
# 5.0

# %%
In [5]: 8/5
# Out:
# 1.6

# %% [markdown]
# ! результат деления всегда с плавающей точкой

# %% [markdown]
# Целые числа (например, 2, 4, 20) имеют **тип int**, а **числа с дробной частью** (например, 5.0, 1.6) имеют **тип float**. О числовых типах мы поговорим позднее.

# %% [markdown]
# Оператор деления / всегда возвращает float. Чтобы выполнить деление нацело и
# получить целочисленный результат (отбрасив дробную часть), вы можете использовать оператор //, а для вычисления остатка — оператор %.

# %%
In [6]: 17/3 # обычное деление с плавающей точкой
# Out:
# 5.666666666666667

# %%
In [7]: 17 // 3 # целочисленное деление
# Out:
# 5

# %%
In [8]: 17 % 3 # остаток от деления
# Out:
# 2

# %%
In [9]: 5*3 + 2 # проверка: результат * делитель + остаток
# Out:
# 17

# %% [markdown]
# Для вычисления степени можно использовать оператор **.

# %%
In [10]: 5 ** 2 # 5 в квадрате
# Out:
# 25

# %%
In [11]: 2 ** 7 # 2 в степени 7
# Out:
# 128

# %% [markdown]
# Знак равенства = используется для присвоения значения переменной. После присвоения результат не отображается:

# %%
In [12]: width = 20
height =5*9
# обратите внимание, что этот код ничего не возвращает

# %% [markdown]
# ##**3.3.2. Строки**

# %% [markdown]
# Помимо чисел Python может также работать со строками, которые можно задавать
# несколькими способами. Они могут быть заключены в одинарные '...' или двойные кавычки "...". Для экранирования кавычек используется символ \:

# %%
In [13]: 'python strings' # одиночные кавычки
# Out:
# 'python strings'

# %%
In [14]: 'doesn\'t' # используйте \ для экранирования кавычки...
# Out:
# "doesn't"

# %%
In [15]: "doesn't" # ...или используйте двойные кавычки
# Out:
# "doesn't"

# %% [markdown]
# В интерактивном интерпретаторе строка вывода заключается в кавычки, а специальные символы экранированы обратной косой чертой. На вид такая строка отличается от ввода (сами кавычки могут быть другими), но эти две строки все равно
# эквивалентны. Строка заключается в двойные кавычки, если содержит внутри себя
# одинарные кавычки и не содержит двойных кавычек, в противном случае строка
# заключается в одинарные кавычки.

# %% [markdown]
# Функция print о позволяет получить более читаемый вывод, опустить кавычки
# и вывести экранированные и специальные символы:

# %%
In [16]: '"Isn\'t," they said.'
# Out:
# '"Isn\'t," they said.'

# %%
In [17]: print('"Isn\'t," they said.')
# Out:
# "Isn't," they said.

# %% [markdown]
# **Если вы не хотите, чтобы управляющие символы (такие как \n, \t) интерпретировались как специальные, вы можете использовать необработанные строки, добавив
# букву г перед первой кавычкой:**

# %%
In [18]: print('C:\some\name') # здесь \п - переход на новую строку!
# Out:
# C:\some
# ame

# %%
In [19]: print(r'C:\some\name') # г перед открывающей кавычкой
# Out:
# C:\some\name

# %% [markdown]
# ##**3.3.2.1. Конкатенация и повторение**

# %% [markdown]
# Строки можно объединять (склеивать) с помощью оператора + и повторять с помощью оператора *. Запомнить это просто.
#
#   Оператор + складывает, а оператор *
# умножает.

# %%
In [20]: 'а' + 'Ь'
# Out:
# 'аЬ'

# %%
In [21]: 't' * 5
# Out:
# 'ttttt'

# %%
In [22]: 'no' * 3 + 'dip'
# Out:
# 'nononodip'

# %% [markdown]
# Два или более строковых литерала (заключенных в кавычки строки), расположенных рядом друг с другом, автоматически объединяются

# %%
In [23]: 'nil' 'abh'
# Out:
# 'nilabh'

# %% [markdown]
# Это особенно удобно, если требуется разделить длинные строки.

# %%
In [23]: text = ('Put several strings within parentheses -'
'- to have them joined together.')
text
# Out:
# 'Put several strings within parentheses -- to have them joined together.'
